# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **ENAANATOR TOM ARUGU**
#
# Data Analyst

# %% [markdown]
# *I want to be a Data Scientist because I want to be able to have deeper knowledge of data and use it to make inform decisions.*

# %% [markdown]
# ### The codes I will write will be carry out addition and multiplication operations respectively.

# %%
# addition operation
12 + 54
# Out:
# 66

# %%
# multiplication

17 * 4
# Out:
# 68

# %% [markdown]
# # horizontal Rule
# --------------------------------------------------
# # bulleted list
# - Camry
# - Avalon
# - Corolla
# - Rav4
#
# # Numbered list
# 1. Camry
# 2. Avalon
# 3. Rav4

# %% [markdown]
# # Objetives of this assignment
#
# 1. Creating a Jupyter Notebook using Skills Network LTI item or Watson Studio environment.
#
# 2. Create Markdown cells.

# %% [markdown]
# # insert image

# %% [markdown]
# ![6123.jpg](attachment:70a89f5f-00a3-411d-9393-f781d0afc81a.jpg)

# %% [markdown]
# ![8898.jpg](attachment:8fbc3256-b9f5-4634-950d-cfde0e6caca8.jpg)

# %% [markdown]
# # Author
# Mr. Enaanator Tom Arugu
